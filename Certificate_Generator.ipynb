# %% [markdown]
# <a href="https://colab.research.google.com/github/siteByteside/Certificate-Generator-Project/blob/main/Certificate_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Downloading & Importing packages for this project

# %%
# !pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.5 MB/s eta 0:00:00
# ...

# %%
# mount google drive (connect this project with google drive)
# we are linking to googledrive because our excel file is there

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

from reportlab.lib.pagesizes import landscape, A4
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont

# %% [markdown]
# ## 2. Reading and Exploring the Excel File

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/dataset.xlsx")

# %%
df

# Realize that 2 of the rows are empty (Row 4 & 8)
# NaT -> Not a Time
# NaN -> Not a Number

# basically empty values (null values)
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 4                    -                    NaN      Advanced        NaT
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 8      Jonathan Bucker                    NaN           NaN        NaT
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# ...

# %%
df.info() # information about the dataset

# 1. non-null (not empty) --> 13 non-null --> none of the 13 rows are empty (there is data)

# From here, we know that there are 4 columns and 13 rows (some are empty)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         13 non-null     object
#  1   Course       11 non-null     object
#  2   CourseLevel  12 non-null     object
#  3   Date         11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 548.0+ bytes

# %%
# before jumping into the next section, ask the students what should be the next step

# a. create cert logic immediately
# b. something else? --> if so, what?

# %% [markdown]
# ## 3. Data Cleaning (Data Analysis)
#
# `Data Cleaning`- Formatting the data before doing the certificate generator logic
#
# * Deal with missing values
# * Format the date tor text

# %%
# the 3 problems with the original dataset (raw excel file)

# 1. Inconsistency formatting in "Course" & "CourseLevel" columns - (some are capitalized but some are uppercase)
# 2. Date format (yyyy/mm/dd) --> we want to change into (xq/mm/yyyy)
# 3. Empty rows (half empty row 4 & 8)

# we are going to solve these problems using Data analysis with Pandas!

# %%
# Problem 3
df = df.dropna() # drop all the rows that have at least 1 empty column

# in this case, row 4 & 8 will be dropped

# %%
df # from 13 to 11 data left
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20

# %%
# Problem 2:  Date format (yyyy/mm/dd) --> we want to change into (dd/mm/yyyy)

df['Date']
# this gives us the "Date" column in pandas Series
# Date format (yyyy/mm/dd) --> we want to change into (dd/mm/yyyy)
# Out:
# 0    2023-09-10
# 1    2023-09-11
# 2    2023-09-12
# 3    2023-09-13
# 5    2023-09-14
# 6    2023-09-15
# 7    2023-09-16
# 9    2023-09-17
# 10   2023-09-18
# 11   2023-09-19
# 12   2023-09-20
# Name: Date, dtype: datetime64[ns]

# %%
# let's look at the first row of 'Date'

# iloc --> index location
df['Date'].iloc[0]

# .iloc[0] --> index location of 0 (the first row)
# Timestamp is a data type to represent time in (excel, df)
# For example, we need to change  Timestamp('2023-09-10 00:00:00') --> "10/09/2023"
# Out:
# Timestamp('2023-09-10 00:00:00')

# %%
# Create a new column called "Formatted Date" and create a
# new date format based off of 'Date' column
# After that, we remove the original 'Date' column

df['FormattedDate'] = df['Date'].dt.strftime('%d/%m/%Y')

# 'dt' in Pandas allows us to format dates
# 'dt' measn datetime here, there are a lot more commands dealing with datetime
# one of the commands in 'dt' is --> strftime
# strftime (string formatted time) --> convert timestamp object into string
# representations (following a specific format)

# Y --> 2023
# y --> 23

# we'll learn how to format advance dates and times in a Pandas chapter in our future lesson

# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
# Out:
# /tmp/ipython-input-3429230824.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FormattedDate'] = df['Date'].dt.strftime('%d/%m/%Y')

# %%
df['FormattedDate'].dtype

# 0 --> Object --> string
# Out:
# dtype('O')

# %%
df.head()
# Out:
#                  Name                 Course   CourseLevel       Date  \
# 0  Christy Cunningham                 Python      Beginner 2023-09-10
# 1      Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2      Travis Walters                   Java  Intermediate 2023-09-12
# 3    Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5        Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
#
#   FormattedDate
# 0    10/09/2023
# 1    11/09/2023
# 2    12/09/2023
# 3    13/09/2023
# 5    14/09/2023

# %%
# Remove the original 'Date' column as it has no use to us now

# reassignment
df = df.drop('Date', axis=1)

# axis 0 -> row
# axis 1 -> col
# we are dropping the 'Date' col

# %%
df.head()
# Out:
#                  Name                 Course   CourseLevel FormattedDate
# 0  Christy Cunningham                 Python      Beginner    10/09/2023
# 1      Douglas Tucker                 PYTHON       MASTER     11/09/2023
# 2      Travis Walters                   Java  Intermediate    12/09/2023
# 3    Nathaniel Harris        Web Development      Advanced    13/09/2023
# 5        Tonya Carter  AI & Machine Learning      Beginner    14/09/2023

# %%
# Problem 1: Inconsistency formatting in 'Course' and 'CourseLevel' columns

# str in Pandas allows us to format string

df['Course'] = df['Course'].str.capitalize()
df['CourseLevel'] = df['CourseLevel'].str.capitalize()

# broadcasting function --> broadcast the logic of capitalization to all the
# rows in the "Course" and "CourseLevel" columns

# we will learn how to format advance strings in a pandas chapter later on

# %%
df.head()
# Out:
#                  Name                 Course   CourseLevel FormattedDate
# 0  Christy Cunningham                 Python      Beginner    10/09/2023
# 1      Douglas Tucker                 Python       Master     11/09/2023
# 2      Travis Walters                   Java  Intermediate    12/09/2023
# 3    Nathaniel Harris        Web development      Advanced    13/09/2023
# 5        Tonya Carter  Ai & machine learning      Beginner    14/09/2023

# %%
# We are done with basic data analysis (Formatting the data!)

# %% [markdown]
# ## 4. Registering Fonts into our Project

# %%
fonts_path = "/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/fonts"

# Defining the path to the fonts folder (it is like storing a string inside 'fonts_path' variable)

# %%
# registering 2 fonts into this project

# pdfmetrics is 1 of the packages we imported
# this package is used to register fonts so that we can use it
# with pdf files

# .ttf is an extension for fonts file

# one of the commands in pdfmetrics is --> registerFont()

# TTFont() is another package we imported!

# TTFont() needs 2 inputs
# 1st input --> what fond are we registering
# 2nd input --> where is the file of the font
#   * (concat the 'fonts folder' with the file)

pdfmetrics.registerFont(TTFont('Lora-Bold', fonts_path + '/Lora-Bold.ttf'))
pdfmetrics.registerFont(TTFont('Lora-Regular', fonts_path + '/Lora-Regular.ttf'))

# %%
#after registering, we can use these fonts in the project later!

# %% [markdown]
# ## 5. Creating Certificate Logic Function
#
# <hr>
#
# ### Version 1 of the Function
# * have `checkpoints` with the students and `use the function from time to time`.
# * when the function is used, ask students to check their `certificates` folder in google drive (refresh a few times)

# %%
# in this function, the logic of creating a cert generator will be inside!
# this function will receive 4 inputs (name,courseName,courseLevel,date)

# we are going to REUSE THIS FUNCTION 11 times (since there are 11 students) - using a for loop to loop through the dataset
# for each student, this function will receive their name, course, level & date (4 inputs)

def certificate_generator(name,courseName,courseLevel,date):

  # store the generated file name inside a variable 'pdf_file_name'
  # E.g., when using this function to create Christy Cunningham's cert
  # the file name will be stored as -> ChristyCunningham-python-beginner.pdf
  pdf_file_name = '/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificates/' + name + '-' + courseName + '-' + courseLevel + '.pdf'

  # canvas = blank screen (A4 landscape size)
  # we are storing this canvas inside this .pdf (file path --> "pdf_file_name")

  # storing it inside a variable called 'c'
  # basically we have a blank landscape A4 virtual paper in our .pdf file

  # Canvas() will need 2 inputs
  # 1st input - where are you storing it?  and the file name
  # 2nd input - what size?

  c = canvas.Canvas(pdf_file_name, pagesize= landscape(A4))

  # the canvas' dragImage() needs 5 inputs
  # 1st input --> image --> what are u drawing on the empty canvas?? --> certifcate template
  # 2nd input --> x axis (coordinate 0)
  # 3rd input --> y axis (coodinate 0)
  # 4th input --> width --> A4[1] (using the A4 variable we imported)(where to start drawing)
  # 5th input --> height --> A4[0] (using the A4 variable we imported)(where to start drawing)

  # 2nd & 3rd --> (x,y) --> (0,0) --> we want to place the image (certificate template) from 0,0 (bottom left corner)
  # 4th & 5th input --> width & height --> how big we want the image (certificate template) to be? --> normal A4 size
  # A4[0] is the short side; A4[1] is the long side
  # A4[0] --> 0 is the index of HEIGHT in landscape
  # A4[1] --> 1 is the index of WIDTH in landscape

  template = '/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificate_template.jpg'

  # It's basically drawing our cert template into the canvas
  c.drawImage(template,0,0,A4[1],A4[0])

  # up until this point, we have an empty A4 landscape canvas
  # that drew with the cert template

  c.save() # save the canvas

# %%
# certificate_generator function needs 4 inputs --> (name,courseName,courseLevel,date)

certificate_generator('Denise','Python','Beginner','11/01/2026')
certificate_generator('Kailey','Web Development','Advanced','12/01/2026')

# after running this, ask the students to check their "certificates" folder in google drive
# they should have 2 certificate templates of A4 landscape size in their .pdf file (different format names)

# %% [markdown]
# ### Version 2 of the Function
#
# * have `checkpoints` with the students and `use the function from time to time`
# * when the function is used, ask students to check their `certificates` folder in google drive (refresh a few times)

# %%
def certificate_generator(name,courseName,courseLevel,date):
  pdf_file_name = '/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificates/' + name + '-' + courseName + '-' + courseLevel + '.pdf'

  c = canvas.Canvas(pdf_file_name,pagesize=landscape(A4))

  c.drawImage('/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificate_template.jpg', 0,0, width=A4[1], height=A4[0])

  # up till this point, we basically have an empty A4 landscape canvas --> drew it with the cert template.

  # Before populating the data (4 inputs --> name,courseName,courseLevel,date) into this certificate...

  # Let's calculate the center of the A4 lanscape page
  # because when we draw the (courseName, courselevel, date), we don't want to start from 0,0 --> top left corner
  # instead (in this context), it will be easier and faster to start from the middle of the page

  print('----------------------') # 22 -
  # middle of the A4 page (width) --> middle because /2
  # index of width, it's stored as the first item in landscape, hence 0
  center_x = c._pagesize[0] / 2

  # crosscheck by printing
  print('Full width of the A4: ', c._pagesize[0]) # full width of the A4 canvas size
  print('Center of the A4 (x-axis): ', center_x) # center A4 canvas size (x-axis)

  print('-----')

  # middle of the A4 page (height) --> middle because /2
  # index of height, it's stored as the second item in landscape, hence 1
  center_y = c._pagesize[1] / 2

  #crosscheck by printing
  print("Full height of the A4: ", c._pagesize[1]) # full height of the A4 canvas size
  print("Center of the A4 (y-axis): ", center_y) # center A4 canvas size (y-axis)
  print('----------------------')

  c.save()

# %%
# certificate_generator function needs 4 inputs --> (name,courseName,courseLevel,date)

certificate_generator('Jessica','Cybersecurity','Master','11/01/2026')
# Out:
# ----------------------
# Full width of the A4:  841.8897637795277
# Center of the A4 (x-axis):  420.94488188976385
# -----
# Full height of the A4:  595.2755905511812
# Center of the A4 (y-axis):  297.6377952755906
# ----------------------

# %% [markdown]
# ### Version 3 of the Function
#
# * have `chekcpoints` with the sudents and `use the function from time to time`
# * when the function is used, ask students to check their `certificates` folder in google drive (refresh a few times)

# %%
def certificate_generator(name,courseName,courseLevel,date):
  pdf_file_name = '/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificates/' + name + '-' + courseName + '-' + courseLevel + '.pdf'

  c = canvas.Canvas(pdf_file_name,pagesize=landscape(A4))

  c.drawImage('/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificate_template.jpg', 0,0, width=A4[1], height=A4[0])

  center_x = c._pagesize[0] / 2
  center_y = c._pagesize[1] / 2

  # now that we got the centre of x & y....
  # Let's now set font and draw text

  #--------------
  # .setFont() --> needs 2 inputs

  # 1st input --> font type
  # 2nd input --> font size (in px)
  #--------------

  #--------------
  # .drawCentredString() --> needs 3 inputs

  # 1st input --> x axis on the canvas to draw
  # 2nd input --> y axis on the canvas to draw
  # 3rd input --> what u are drawing on the canvas
  #--------------

  # 1.Name
  c.setFont('Lora-Bold', 30)
  c.drawCentredString(center_x, center_y - 46, name)

  # 2. CourseName & CourseLevel
  c.setFont('Lora-Bold', 28)
  c.drawCentredString(center_x, center_y - 105, courseName + ' - ' + courseLevel)

  # 3. Date
  c.setFont('Lora-Bold', 17)
  c.drawCentredString(center_x + 190, center_y - 160, date)

  # 4. Cert ID (Check cell below before coding this)
  cert_id = 'Cert_ID: ' + str(pd.Timestamp.now().timestamp()).replace('.','') # Generating a UNIQUE id based on current time (timestamp)
  c.setFont('Lora-Regular', 12)
  c.drawCentredString(center_x + 266, center_y - 230, cert_id.upper())

  c.save()

# %%
# For CERT ID, it has to be unique, we can uniquely generate an ID based on current time (using pd.Timestamp)
print(pd.Timestamp.now())
print(pd.Timestamp.now().timestamp()) # Unix timestamp (number of seconds since January 1 1970)
print(str(pd.Timestamp.now().timestamp()).replace('.', ''))

# Unix time is a way of representing a timestamp by representing the time as the number of seconds since January 1st, 1970 at 00:00:00 UTC.
# Out:
# 2026-01-02 10:51:39.590767
# 1767351099.590961
# 1767351099591086

# %%
# later on we are going to loop through the df
# looping takes time - that's why we are using timestamp as our unique id as the milliseconds are different

for x in range(10):
  print(pd.Timestamp.now())
# Out:
# 2026-01-02 10:52:51.190315
# 2026-01-02 10:52:51.190405
# 2026-01-02 10:52:51.190432
# 2026-01-02 10:52:51.190447
# 2026-01-02 10:52:51.190457
# 2026-01-02 10:52:51.190467
# 2026-01-02 10:52:51.190476
# 2026-01-02 10:52:51.190485
# 2026-01-02 10:52:51.190496
# 2026-01-02 10:52:51.190506

# %%
# certificate_generator function needs 4 inputs --> (name,courseName,courseLevel,date)

certificate_generator('Denise Choo','Python','Advanced','14/07/2026')

# %% [markdown]
# ### Version 4 of the Function

# %%
def certificate_generator(name,courseName,courseLevel,date):
  pdf_file_name = '/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificates/' + name + '-' + courseName + '-' + courseLevel + '.pdf'

  c = canvas.Canvas(pdf_file_name,pagesize=landscape(A4))

  c.drawImage('/content/drive/MyDrive/Colab Notebooks/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificate_template.jpg', 0,0, width=A4[1], height=A4[0])

  center_x = c._pagesize[0] / 2
  center_y = c._pagesize[1] / 2

  # 1.Name
  c.setFont('Lora-Bold', 30)
  c.drawCentredString(center_x, center_y - 46, name)

  # 2. CourseName & CourseLevel
  c.setFont('Lora-Bold', 28)
  c.drawCentredString(center_x, center_y - 105, courseName + ' - ' + courseLevel)

  # 3. Date
  c.setFont('Lora-Bold', 17)
  c.drawCentredString(center_x + 190, center_y - 160, date)

  # 4. Cert ID (Check cell below before coding this)
  cert_id = 'Cert_ID: ' + str(pd.Timestamp.now().timestamp()).replace('.','')
  c.setFont('Lora-Regular', 12)
  c.drawCentredString(center_x + 266, center_y - 230, cert_id.upper())

  c.save()

# %%
# instead of using the function manually like we did,
# we are going to loop through all the rows in the DATAFRAME
df
# Out:
#                   Name                 Course   CourseLevel FormattedDate
# 0   Christy Cunningham                 Python      Beginner    10/09/2023
# 1       Douglas Tucker                 Python       Master     11/09/2023
# 2       Travis Walters                   Java  Intermediate    12/09/2023
# 3     Nathaniel Harris        Web development      Advanced    13/09/2023
# 5         Tonya Carter  Ai & machine learning      Beginner    14/09/2023
# 6           Erik Smith     Mobile development      Beginner    15/09/2023
# 7   Kristopher Johnson                 Python      Beginner    16/09/2023
# 9          Robert Buck                 Python       Master     17/09/2023
# 10     Joseph Mcdonald                   Java  Intermediate    18/09/2023
# 11       Jerome Abbott        Web development      Advanced    19/09/2023
# 12       William Riley  Ai & machine learning      Beginner    20/09/2023

# %%
# there are 11 students, the idea is USING THE FUNCTION
# 11 TIMES (with different 4 inputs --> (name,courseName,courseLevel,date))

# use a for loop --> loop 11 times --> use function 11 times based on different 4 inputs

#Generate certificates for each row in the DataFrame (11rows)
#execute this function 11 times --> generate 11 certs

#remember we can loop through an array with a for loop
for x in ["Big","Red","Apple"]:
  print(x)
# Out:
# Big
# Red
# Apple

# %%
# enumerate() keeps track of the index of each item
for index, x in enumerate(['Big', 'Red', 'Apple']):
  print(f"{index} {x}")
# Out:
# 0 Big
# 1 Red
# 2 Apple

# %%
# again we need to loop through the df

# but this is not how u loop through each row

# this will loop through the columns

for x in df:
  print(x)
# Out:
# Name
# Course
# CourseLevel
# FormattedDate

# %%
# df.iterrows gives u a loopable (array-like)
# df.iterrows gives you 2 items (index, item(row))

for index, x in df.iterrows():
  print(index)
# Out:
# 0
# 1
# 2
# 3
# 5
# 6
# 7
# 9
# 10
# 11
# 12

# %%
df
# Out:
#                   Name                 Course   CourseLevel FormattedDate
# 0   Christy Cunningham                 Python      Beginner    10/09/2023
# 1       Douglas Tucker                 Python       Master     11/09/2023
# 2       Travis Walters                   Java  Intermediate    12/09/2023
# 3     Nathaniel Harris        Web development      Advanced    13/09/2023
# 5         Tonya Carter  Ai & machine learning      Beginner    14/09/2023
# 6           Erik Smith     Mobile development      Beginner    15/09/2023
# 7   Kristopher Johnson                 Python      Beginner    16/09/2023
# 9          Robert Buck                 Python       Master     17/09/2023
# 10     Joseph Mcdonald                   Java  Intermediate    18/09/2023
# 11       Jerome Abbott        Web development      Advanced    19/09/2023
# 12       William Riley  Ai & machine learning      Beginner    20/09/2023

# %%
for index, x in df.iterrows():
  print(x)
  print('-' * 40)
# Out:
# Name             Christy Cunningham
# Course                       Python
# CourseLevel                Beginner
# FormattedDate            10/09/2023
# Name: 0, dtype: object
# ----------------------------------------
# Name             Douglas Tucker
# Course                   Python
# CourseLevel             Master
# FormattedDate        11/09/2023
# Name: 1, dtype: object
# ----------------------------------------
# Name             Travis Walters
# Course                     Java
# CourseLevel        Intermediate
# FormattedDate        12/09/2023
# Name: 2, dtype: object
# ----------------------------------------
# Name             Nathaniel Harris
# Course            Web development
# CourseLevel              Advanced
# FormattedDate          13/09/2023
# Name: 3, dtype: object
# ----------------------------------------
# Name                      Tonya Carter
# Course           Ai & machine learning
# CourseLevel                   Beginner
# ...

# %%
for index, x in df.iterrows():
  certificate_generator(x['Name'], x['Course'], x['CourseLevel'], x['FormattedDate'])

print(f"{len(df)} certificates generated successfully.")
# Out:
# 11 certificates generated successfully.

# %% [markdown]
# # END!
#
# - Explain again how this project is related to `Data Analysis`
# - Ask for student's feedback on their first business project `would appreciate if the feedbacks are passed to me :D`
# - Reassure the students `this project & upcoming projects` will be posted on `GitHub` to build up their resume `in future lessons`
# - For this project, assist them to post it on GitHub. Make sure they have a GitHub account. `File` → `Save a copy in GitHub`
